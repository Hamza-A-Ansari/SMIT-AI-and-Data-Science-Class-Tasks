# %%
# Import necessary modules
import numpy as np
from numpy import asarray
from PIL import Image

# %%
# Load image
img = Image.open("images.jfif")

# %%
# Print image
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x1BDF58351F0>

# %%
# Convert image to Numpy array
num_data = asarray(img)

# %%
num_data
# Out:
# array([[[ 58,  82,   4],
#         [ 58,  82,   4],
#         [ 58,  82,   4],
#         ...,
#         [ 66,  90,   4],
#         [ 65,  89,   3],
#         [ 65,  89,   5]],
#
#        [[ 58,  82,   4],
#         [ 58,  82,   4],
#         [ 58,  82,   4],
#         ...,
#         [ 66,  90,   4],
#         [ 65,  89,   3],
#         [ 65,  89,   3]],
#
#        [[ 57,  81,   3],
#         [ 57,  81,   3],
#         [ 57,  81,   3],
#         ...,
#         [ 66,  90,   4],
#         [ 66,  90,   4],
#         [ 65,  89,   3]],
#
#        ...,
#
#        [[ 59,  87,   3],
#         [ 59,  87,   3],
#         [ 59,  87,   3],
#         ...,
#         [128, 144,  35],
#         [125, 141,  32],
#         [123, 139,  32]],
#
#        [[ 59,  87,   3],
#         [ 59,  87,   3],
#         [ 59,  87,   3],
#         ...,
#         [127, 142,  41],
#         [125, 139,  41],
#         [124, 138,  40]],
#
#        [[ 60,  88,   4],
#         [ 60,  88,   4],
#         [ 60,  88,   4],
# ...

# %%
# Convert RGB to Greyscale
a = num_data[:,:,0]

# %%
a
# Out:
# array([[ 58,  58,  58, ...,  66,  65,  65],
#        [ 58,  58,  58, ...,  66,  65,  65],
#        [ 57,  57,  57, ...,  66,  66,  65],
#        ...,
#        [ 59,  59,  59, ..., 128, 125, 123],
#        [ 59,  59,  59, ..., 127, 125, 124],
#        [ 60,  60,  60, ..., 127, 125, 125]], dtype=uint8)

# %%
data = Image.fromarray(a)
data
# Out:
# <PIL.Image.Image image mode=L size=224x224 at 0x1BDF5E660D0>
